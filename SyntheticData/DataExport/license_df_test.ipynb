# %%
# Imports for all modules needed.
import sys
import pandas as pd
sys.path.append('../DataGeneration')
from license_data_generator import License, Corrupt, Validate, Stats

# %%
# Testing the output of generate_dataset().
test_dataset = License.generate_dataset(10)
test_dataset.head()
# Out:
#   First Name Last Name Date of Birth           Place of Birth  Gender  \
# 0        Zoe  Harrison    26.08.2006                  Bahrain    Male
# 1        Roy     Jones    10.11.1994                     Mali  Female
# 2  Catherine     Mason    03.08.1990                   France    Male
# 3      Colin   Howarth    24.10.1973                    Gabon    Male
# 4    Natalie   Simpson    31.08.1992  Cocos (Keeling) Islands    Male
#
#   Date of Issue Date of Expiry Issuing Authority    License Number  \
# 0    24.09.2023     21.09.2033               DA1  HARRI008266Z99MC
# 1    04.06.2013     02.06.2023               DA1  JONES961104R99GN
# 2    29.09.2008     27.09.2018               DA1  MASON908030C99GF
# 3    13.08.2012     11.08.2022               DA1  HOWAR710243C99NR
# 4    18.10.2010     15.10.2020               DA1  SIMPS908312N99XC
#
#                                           Address
# 0        923 Hooper point, Robertshaven, LD5N 0EJ
# 1           820 Douglas drive, Brownland, G34 9QT
# 2          205 Elaine passage, Ronaldberg, M7 6AJ
# 3             964 Chan lights, East Adam, N95 1TL
# 4  882 Jackson bridge, North Grahamfort, PR73 1LZ

# %%
# Testing the Corruption functions by corrupting the test dataset from above.
corrupted_test_dataset = Corrupt.introduce_corruptions(test_dataset, 0)
corrupted_test_dataset.head()
# Out:
#   First Name Last Name Date of Birth           Place of Birth  Gender  \
# 0        Zoe  Harrison    26.08.2006                  Bahrain    Male
# 1        Roy     Jones    10.11.1994                     Mali  Female
# 2  Catherine     Mason    03.08.1990                   France    Male
# 3      Colin   Howarth    24.10.1973                    Gabon    Male
# 4    Natalie   Simpson    31.08.1992  Cocos (Keeling) Islands    Male
#
#   Date of Issue Date of Expiry Issuing Authority    License Number  \
# 0    24.09.2023     21.09.2033               DA1  HARRI008266Z99MC
# 1    04.06.2013     02.06.2023               DA1  JONES961104R99GN
# 2    29.09.2008     27.09.2018               DA1  MASON908030C99GF
# 3    13.08.2012     11.08.2022               DA1  HOWAR710243C99NR
# 4    18.10.2010     15.10.2020               DA1  SIMPS908312N99XC
#
#                                           Address
# 0        923 Hooper point, Robertshaven, LD5N 0EJ
# 1           820 Douglas drive, Brownland, G34 9QT
# 2          205 Elaine passage, Ronaldberg, M7 6AJ
# 3             964 Chan lights, East Adam, N95 1TL
# 4  882 Jackson bridge, North Grahamfort, PR73 1LZ

# %%
# Testing the Validation functions by validating the corrupted data from above. 
validated_test_dataset = Validate.validate(corrupted_test_dataset)
validated_test_dataset.head()
# Out:
#   First Name  First Name Corruption Last Name  Last Name Corruption  \
# 0        Zoe                      0  Harrison                     0
# 1        Roy                      0     Jones                     0
# 2  Catherine                      0     Mason                     0
# 3      Colin                      0   Howarth                     0
# 4    Natalie                      0   Simpson                     0
#
#   Date of Birth  Date of Birth Corruption           Place of Birth  \
# 0    26.08.2006                         0                  Bahrain
# 1    10.11.1994                         0                     Mali
# 2    03.08.1990                         0                   France
# 3    24.10.1973                         0                    Gabon
# 4    31.08.1992                         0  Cocos (Keeling) Islands
#
#    Place of Birth Corruption  Gender  Gender Corruption Date of Issue  \
# 0                          0    Male                  0    24.09.2023
# 1                          0  Female                  0    04.06.2013
# 2                          0    Male                  0    29.09.2008
# 3                          0    Male                  0    13.08.2012
# 4                          1    Male                  0    18.10.2010
#
#    Date of Issue Corruption Date of Expiry  Date of Expiry Corruption  \
# 0                         0     21.09.2033                          0
# 1                         0     02.06.2023                          0
# 2                         0     27.09.2018                          0
# 3                         0     11.08.2022                          0
# 4                         0     15.10.2020                          0
#
#   Issuing Authority  Issuing Authority Corruption    License Number  \
# 0               DA1                             0  HARRI008266Z99MC
# 1               DA1                             0  JONES961104R99GN
# 2               DA1                             0  MASON908030C99GF
# 3               DA1                             0  HOWAR710243C99NR
# 4               DA1                             0  SIMPS908312N99XC
#
#    License Number Corruption                                         Address  \
# 0                          0        923 Hooper point, Robertshaven, LD5N 0EJ
# 1                          0           820 Douglas drive, Brownland, G34 9QT
# 2                          0          205 Elaine passage, Ronaldberg, M7 6AJ
# 3                          0             964 Chan lights, East Adam, N95 1TL
# 4                          0  882 Jackson bridge, North Grahamfort, PR73 1LZ
#
#    Address Corruption
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0

# %%
# Checking the Stats functions.
corrupt = Stats.is_corrupt(validated_test_dataset)
corrupt
# Out:
# 1

# %%
# Checking the Stats functions.
corrupt_percentage = Stats.corrupt_percent(validated_test_dataset)
corrupt_percentage
# Out:
# 0.01

# %%
# Checking the Stats functions.
corrupt_attributes = Stats.attribute_corruption(validated_test_dataset)
corrupt_attributes
# Out:
# {'First Name': 0,
#  'Last Name': 0,
#  'Date of Birth': 0,
#  'Place of Birth': 1,
#  'Gender': 0,
#  'Date of Issue': 0,
#  'Date of Expiry': 0,
#  'Issuing Authority': 0,
#  'License Number': 0,
#  'Address': 0}
